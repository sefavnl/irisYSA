# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow import keras
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
labels = df.pop('species')

# %%
labels = pd.get_dummies(labels)

# %%
labels.head()
# Out:
#    setosa  versicolor  virginica
# 0       1           0          0
# 1       1           0          0
# 2       1           0          0
# 3       1           0          0
# 4       1           0          0

# %%
x = df.values
y = labels.values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.15)

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(16, activation='relu', input_shape=(4,)))
model.add(keras.layers.Dense(3, activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = keras.Sequential()
#       2 model.add(keras.layers.Dense(16, activation='relu', input_shape=(4,)))
#       3 model.add(keras.layers.Dense(3, activation='softmax'))
#
# NameError: name 'keras' is not defined

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
#       2 model.fit(x_train, y_train,
#       3            batch_size=12,
#       4            epochs=100,
#       5            validation_data=(x_val, y_val))
#
# NameError: name 'model' is not defined

# %%
model.compile(optimizer='sgd',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1238 - accuracy: 0.9558 - val_loss: 0.1009 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1215 - accuracy: 0.9646 - val_loss: 0.1005 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1195 - accuracy: 0.9646 - val_loss: 0.1004 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1194 - accuracy: 0.9558 - val_loss: 0.0994 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1178 - accuracy: 0.9735 - val_loss: 0.0995 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1174 - accuracy: 0.9558 - val_loss: 0.0968 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model.compile(optimizer='Adamax',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0969 - accuracy: 0.9646 - val_loss: 0.0703 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0942 - accuracy: 0.9646 - val_loss: 0.0688 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0933 - accuracy: 0.9646 - val_loss: 0.0680 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0930 - accuracy: 0.9646 - val_loss: 0.0678 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0929 - accuracy: 0.9646 - val_loss: 0.0676 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.9646 - val_loss: 0.0675 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model.compile(optimizer='Nadam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model.compile(optimizer='Nadam',loss='binary_crossentropy',metrics=['accuracy'])
#       2 model.fit(x_train, y_train,
#       3            batch_size=12,
#       4            epochs=100,
#       5            validation_data=(x_val, y_val))
#
# NameError: name 'model' is not defined

# %%
model.compile(optimizer='Nadam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 12ms/step - loss: 0.0922 - accuracy: 0.9646 - val_loss: 0.0654 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0909 - accuracy: 0.9646 - val_loss: 0.0648 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0904 - accuracy: 0.9646 - val_loss: 0.0644 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0903 - accuracy: 0.9646 - val_loss: 0.0645 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0902 - accuracy: 0.9735 - val_loss: 0.0639 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0900 - accuracy: 0.9646 - val_loss: 0.0631 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model.compile(optimizer='Nadam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 17ms/step - loss: 0.2826 - accuracy: 0.9027 - val_loss: 0.2683 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2712 - accuracy: 0.9469 - val_loss: 0.2524 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2671 - accuracy: 0.9646 - val_loss: 0.2463 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2643 - accuracy: 0.9646 - val_loss: 0.2428 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2625 - accuracy: 0.9646 - val_loss: 0.2396 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2594 - accuracy: 0.9558 - val_loss: 0.2407 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model.compile(optimizer='Nadam',loss='huber',metrics=['accuracy'])
model.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 12ms/step - loss: 0.0110 - accuracy: 0.9558 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 0.9558 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 0.9646 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9735 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 0.9735 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 0.9646 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model.compile(optimizer='Nadam',loss='hinge',metrics=['accuracy'])
model.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 13ms/step - loss: 0.7253 - accuracy: 0.9646 - val_loss: 0.7038 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7242 - accuracy: 0.9646 - val_loss: 0.7034 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7237 - accuracy: 0.9646 - val_loss: 0.7031 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7234 - accuracy: 0.9646 - val_loss: 0.7027 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7237 - accuracy: 0.9735 - val_loss: 0.7023 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7238 - accuracy: 0.9646 - val_loss: 0.7024 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model.compile(optimizer='Nadam',loss='mean_squared_error',metrics=['accuracy'])
model.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 12ms/step - loss: 0.0158 - accuracy: 0.9646 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 0.9646 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 0.9646 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9735 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 0.9823 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 0.9646 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model2 = keras.Sequential()
model2.add(keras.layers.Dense(16, activation='leaky_relu', input_shape=(4,)))
model2.add(keras.layers.Dense(3, activation='softmax'))

# %%
model2.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model2.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 13ms/step - loss: 1.0408 - accuracy: 0.3451 - val_loss: 0.9650 - val_accuracy: 0.2414
# Epoch 2/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9064 - accuracy: 0.3540 - val_loss: 0.8559 - val_accuracy: 0.2759
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8121 - accuracy: 0.3628 - val_loss: 0.7845 - val_accuracy: 0.2759
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7527 - accuracy: 0.3540 - val_loss: 0.7398 - val_accuracy: 0.2414
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7102 - accuracy: 0.3451 - val_loss: 0.7113 - val_accuracy: 0.2414
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6873 - accuracy: 0.3451 - val_loss: 0.6902 - val_accuracy: 0.2414
# Epoch 7/100
# ...

# %%
model2.compile(optimizer='sgd',loss='binary_crossentropy',metrics=['accuracy'])
model2.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.2614 - accuracy: 0.9204 - val_loss: 0.2598 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2613 - accuracy: 0.9381 - val_loss: 0.2624 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2589 - accuracy: 0.9381 - val_loss: 0.2640 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2582 - accuracy: 0.9381 - val_loss: 0.2607 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2593 - accuracy: 0.9469 - val_loss: 0.2652 - val_accuracy: 0.9655
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2574 - accuracy: 0.9292 - val_loss: 0.2627 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model2.compile(optimizer='Adamax',loss='binary_crossentropy',metrics=['accuracy'])
model2.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.2271 - accuracy: 0.9204 - val_loss: 0.2349 - val_accuracy: 0.9655
# Epoch 2/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2245 - accuracy: 0.9381 - val_loss: 0.2297 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2234 - accuracy: 0.9381 - val_loss: 0.2272 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2229 - accuracy: 0.9469 - val_loss: 0.2260 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2231 - accuracy: 0.9646 - val_loss: 0.2242 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2225 - accuracy: 0.9558 - val_loss: 0.2243 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model2.compile(optimizer='Nadam',loss='binary_crossentropy',metrics=['accuracy'])
model2.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 13ms/step - loss: 0.2002 - accuracy: 0.9646 - val_loss: 0.1944 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1989 - accuracy: 0.9646 - val_loss: 0.1921 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1980 - accuracy: 0.9646 - val_loss: 0.1921 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1972 - accuracy: 0.9646 - val_loss: 0.1923 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1974 - accuracy: 0.9735 - val_loss: 0.1909 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1965 - accuracy: 0.9646 - val_loss: 0.1922 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model2.compile(optimizer='Nadam',loss='binary_crossentropy',metrics=['accuracy'])
model2.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 12ms/step - loss: 0.6639 - accuracy: 0.3451 - val_loss: 0.6643 - val_accuracy: 0.2414
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6563 - accuracy: 0.3451 - val_loss: 0.6565 - val_accuracy: 0.2414
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6470 - accuracy: 0.3451 - val_loss: 0.6486 - val_accuracy: 0.2414
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6378 - accuracy: 0.3451 - val_loss: 0.6423 - val_accuracy: 0.2414
# Epoch 5/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6310 - accuracy: 0.3451 - val_loss: 0.6378 - val_accuracy: 0.2414
# Epoch 6/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6258 - accuracy: 0.3451 - val_loss: 0.6363 - val_accuracy: 0.2414
# Epoch 7/100
# ...

# %%
model2.compile(optimizer='Nadam',loss='categorical_crossentropy',metrics=['accuracy'])
model2.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 13ms/step - loss: 0.1632 - accuracy: 0.9558 - val_loss: 0.1120 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1524 - accuracy: 0.9558 - val_loss: 0.1070 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1498 - accuracy: 0.9646 - val_loss: 0.1040 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1473 - accuracy: 0.9646 - val_loss: 0.1012 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1457 - accuracy: 0.9646 - val_loss: 0.0986 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1448 - accuracy: 0.9646 - val_loss: 0.0971 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model2.compile(optimizer='Nadam',loss='huber',metrics=['accuracy'])
model2.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 12ms/step - loss: 0.0085 - accuracy: 0.9646 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 0.9646 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 0.9558 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 0.9735 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9823 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 0.9558 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model2.compile(optimizer='Nadam',loss='hinge',metrics=['accuracy'])
model2.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 15ms/step - loss: 0.7059 - accuracy: 0.9735 - val_loss: 0.6819 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7041 - accuracy: 0.9558 - val_loss: 0.6811 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7040 - accuracy: 0.9646 - val_loss: 0.6810 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7041 - accuracy: 0.9646 - val_loss: 0.6820 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7043 - accuracy: 0.9735 - val_loss: 0.6813 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7050 - accuracy: 0.9646 - val_loss: 0.6800 - val_accuracy: 1.0000
# Epoch 7/100
# ...

# %%
model2.compile(optimizer='Nadam',loss='mean_squared_error',metrics=['accuracy'])
model2.fit(x_train, y_train,
           batch_size=12,
           epochs=100,
           validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 11ms/step - loss: 0.0151 - accuracy: 0.9646 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 0.9646 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 0.9646 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9823 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 5/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9823 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9646 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 7/100
# ...
